# %%
# !pip install pmdarima
# setting logging to print only error messages from Sklearnex
import logging
logging.basicConfig()
logging.getLogger("SKLEARNEX").setLevel(logging.ERROR)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from datetime import datetime

from statsmodels.tsa.stattools import adfuller,kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima

from sklearn.metrics import mean_squared_error,mean_absolute_error
import math

import warnings
warnings.filterwarnings("ignore")

sns.set_theme(palette="Set2")


def get_mda(y, yhat):
    """Mean Directional Accuracy, as per:
    https://www.wikiwand.com/en/Mean_Directional_Accuracy
    """
    a = np.sign(np.diff(y))
    b = np.sign(np.diff(yhat))
    return np.sum(a == b)/a.shape[0]
# Out:
# Requirement already satisfied: pmdarima in c:\users\akash\anaconda\lib\site-packages (2.0.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: urllib3 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.26.9)
# Requirement already satisfied: joblib>=0.11 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.22.4)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (61.2.0)
# Requirement already satisfied: pandas>=0.19 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\akash\anaconda\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akash\anaconda\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\akash\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\akash\anaconda\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\akash\anaconda\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\akash\anaconda\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\akash\anaconda\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.4)

# %%
df=pd.read_csv("GOOGLE  BP DATA.csv")

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close       Volume  \
# 0  01-04-2014  27.859013  28.344681  27.859013  28.280355     158434.0
# 1  02-04-2014  29.917362  30.158699  28.032537  28.272379    2942055.0
# 2  03-04-2014  28.414488  29.283602  28.129271  28.409002  101983228.0
# 3  04-04-2014  28.653831  28.809404  27.075665  27.082645  127386783.0
# 4  07-04-2014  26.962973  27.348913  26.285334  26.833828   88033033.0
#
#    Day of the week    Change       NASDAQ
# 0              3.0 -0.007976  3658.399902
# 1              4.0  0.136623  3665.989990
# 2              5.0 -1.326357  3637.580078
# 3              6.0 -0.248817  3539.379883
# 4              2.0  0.835207  3507.750000

# %%
df = df.iloc[:-62, :]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2267 entries, 0 to 2266
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             2205 non-null   object
#  1   Open             2205 non-null   float64
#  2   High             2205 non-null   float64
#  3   Low              2205 non-null   float64
#  4   Close            2205 non-null   float64
#  5   Volume           2205 non-null   float64
#  6   Day of the week  2205 non-null   float64
#  7   Change           2205 non-null   float64
#  8   NASDAQ           2205 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 159.5+ KB

# %% [markdown]
# ## Convert the "time" column to the datetime type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2267 entries, 0 to 2266
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             2205 non-null   object
#  1   Open             2205 non-null   float64
#  2   High             2205 non-null   float64
#  3   Low              2205 non-null   float64
#  4   Close            2205 non-null   float64
#  5   Volume           2205 non-null   float64
#  6   Day of the week  2205 non-null   float64
#  7   Change           2205 non-null   float64
#  8   NASDAQ           2205 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 159.5+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2267 entries, 0 to 2266
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             2205 non-null   datetime64[ns]
#  1   Open             2205 non-null   float64
#  2   High             2205 non-null   float64
#  3   Low              2205 non-null   float64
#  4   Close            2205 non-null   float64
#  5   Volume           2205 non-null   float64
#  6   Day of the week  2205 non-null   float64
#  7   Change           2205 non-null   float64
#  8   NASDAQ           2205 non-null   float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 159.5 KB

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Day of the week',
#        'Change', 'NASDAQ'],
#       dtype='object')

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#                  Open       High        Low      Close       Volume  \
# Date
# 2014-01-04  27.859013  28.344681  27.859013  28.280355     158434.0
# 2014-02-04  29.917362  30.158699  28.032537  28.272379    2942055.0
# 2014-03-04  28.414488  29.283602  28.129271  28.409002  101983228.0
# 2014-04-04  28.653831  28.809404  27.075665  27.082645  127386783.0
# 2014-07-04  26.962973  27.348913  26.285334  26.833828   88033033.0
#
#             Day of the week    Change       NASDAQ
# Date
# 2014-01-04              3.0 -0.007976  3658.399902
# 2014-02-04              4.0  0.136623  3665.989990
# 2014-03-04              5.0 -1.326357  3637.580078
# 2014-04-04              6.0 -0.248817  3539.379883
# 2014-07-04              2.0  0.835207  3507.750000

# %%
df.drop(['Open', 'High','Low','Day of the week','Change','NASDAQ','Volume'], axis=1,inplace=True)

# %%
df
# Out:
#                 Close
# Date
# 2014-01-04  28.280355
# 2014-02-04  28.272379
# 2014-03-04  28.409002
# 2014-04-04  27.082645
# 2014-07-04  26.833828
# ...               ...
# NaT               NaN
# NaT               NaN
# NaT               NaN
# NaT               NaN
# NaT               NaN
#
# [2267 rows x 1 columns]

# %% [markdown]
# # Missing entries

# %%
min(df.index)
# Out:
# Timestamp('2014-01-04 00:00:00')

# %%
max(df.index)
# Out:
# Timestamp('2022-12-30 00:00:00')

# %%
all_datetimes = pd.date_range(min(df.index), max(df.index), freq="D")
all_datetimes
# Out:
# DatetimeIndex(['2014-01-04', '2014-01-05', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-11',
#                '2014-01-12', '2014-01-13',
#                ...
#                '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-24',
#                '2022-12-25', '2022-12-26', '2022-12-27', '2022-12-28',
#                '2022-12-29', '2022-12-30'],
#               dtype='datetime64[ns]', length=3283, freq='D')

# %%
all_datetimes.shape
# Out:
# (3283,)

# %% [markdown]
# # Supplying missing values

# %% [markdown]
# ## Insert missing datetimes

# %%
all_datetimes_df = pd.DataFrame(index=all_datetimes)
all_datetimes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3283 entries, 2014-01-04 to 2022-12-30
# Freq: D
# Empty DataFrame

# %%
df = pd.merge(all_datetimes_df, df, how="left", left_index=True, right_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3283 entries, 2014-01-04 to 2022-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2205 non-null   float64
# dtypes: float64(1)
# memory usage: 51.3 KB

# %%
plot = df.head(3619).plot(figsize=(20, 12))

# %% [markdown]
# # forward fill

# %%
df["ffilled"] = df["Close"].ffill()
df.head(12)
# Out:
#                 Close    ffilled
# 2014-01-04  28.280355  28.280355
# 2014-01-05  26.494759  26.494759
# 2014-01-06        NaN  26.494759
# 2014-01-07  29.053734  29.053734
# 2014-01-08  28.226006  28.226006
# 2014-01-09        NaN  28.226006
# 2014-01-10  28.335705  28.335705
# 2014-01-11        NaN  28.335705
# 2014-01-12  26.616922  26.616922
# 2014-01-13        NaN  26.616922
# 2014-01-14        NaN  26.616922
# 2014-01-15        NaN  26.616922

# %%
df = df[["ffilled", "Close"]]
plot = df.head(3619).plot(figsize=(20, 12))

# %%
df.ffilled
# Out:
# 2014-01-04    28.280355
# 2014-01-05    26.494759
# 2014-01-06    26.494759
# 2014-01-07    29.053734
# 2014-01-08    28.226006
#                 ...
# 2022-12-26    89.809998
# 2022-12-27    87.930000
# 2022-12-28    86.459999
# 2022-12-29    88.949997
# 2022-12-30    88.730003
# Name: ffilled, Length: 3283, dtype: float64

# %%
df.rename(columns={"ffilled": "close"}, inplace=True)
df
# Out:
#                 close      Close
# 2014-01-04  28.280355  28.280355
# 2014-01-05  26.494759  26.494759
# 2014-01-06  26.494759        NaN
# 2014-01-07  29.053734  29.053734
# 2014-01-08  28.226006  28.226006
# ...               ...        ...
# 2022-12-26  89.809998        NaN
# 2022-12-27  87.930000  87.930000
# 2022-12-28  86.459999  86.459999
# 2022-12-29  88.949997  88.949997
# 2022-12-30  88.730003  88.730003
#
# [3283 rows x 2 columns]

# %%
df.drop(["Close"],axis=1,inplace=True)

# %%
df
# Out:
#                 close
# 2014-01-04  28.280355
# 2014-01-05  26.494759
# 2014-01-06  26.494759
# 2014-01-07  29.053734
# 2014-01-08  28.226006
# ...               ...
# 2022-12-26  89.809998
# 2022-12-27  87.930000
# 2022-12-28  86.459999
# 2022-12-29  88.949997
# 2022-12-30  88.730003
#
# [3283 rows x 1 columns]

# %%
#plot close price
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df['close'])
plt.title('AMAZON closing price')
plt.show()

# %% [markdown]
# # Checking stationarity of the data

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    
    plt.figure(figsize=(18, 10))

    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
test_stationarity(df.close)
# Out:
# Results of dickey fuller test
# Test Statistics                  -0.410916
# p-value                           0.908260
# No. of lags used                 29.000000
# Number of observations used    3253.000000
# critical value (1%)              -3.432362
# critical value (5%)              -2.862429
# critical value (10%)             -2.567243
# dtype: float64

# %% [markdown]
# ## Differencing

# %%
diff_df=df.diff()
diff_df
# Out:
#                close
# 2014-01-04       NaN
# 2014-01-05 -1.785596
# 2014-01-06  0.000000
# 2014-01-07  2.558975
# 2014-01-08 -0.827728
# ...              ...
# 2022-12-26  0.000000
# 2022-12-27 -1.879998
# 2022-12-28 -1.470001
# 2022-12-29  2.489998
# 2022-12-30 -0.219994
#
# [3283 rows x 1 columns]

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
#split data into train and training set
#train_data, test_data = df[3:int(len(df)*0.9)], df[int(len(df)*0.9):]
train_data = df.loc[df.index < '01-04-2022']
test_data = df.loc[df.index >= '01-04-2022']
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %% [markdown]
# # AUTO ARIMA

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=1,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16822.709, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=16802.164, Time=0.28 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=16799.502, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16820.916, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=16591.400, Time=2.20 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=16790.429, Time=1.12 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=16790.180, Time=1.41 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=16793.551, Time=0.61 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=16794.044, Time=0.34 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=16590.830, Time=2.81 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=16592.656, Time=4.36 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=16592.621, Time=4.85 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=16592.137, Time=1.94 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=16792.392, Time=2.01 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=16565.682, Time=6.34 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=16573.900, Time=2.53 sec
#
# Best model:  ARIMA(3,1,3)(0,0,0)[0] intercept
# Total fit time: 31.389 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2922
# Model:               SARIMAX(3, 1, 3)   Log Likelihood               -8274.841
# Date:                Sun, 24 Sep 2023   AIC                          16565.682
# Time:                        22:11:40   BIC                          16613.520
# Sample:                    01-04-2014   HQIC                         16582.912
#                          - 01-03-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0202      0.007      2.863      0.004       0.006       0.034
# ar.L1         -0.0552      0.019     -2.968      0.003      -0.092      -0.019
# ar.L2         -0.2228      0.020    -11.092      0.000      -0.262      -0.183
# ar.L3          0.7624      0.014     53.768      0.000       0.735       0.790
# ma.L1         -0.1381      0.020     -7.037      0.000      -0.177      -0.100
# ma.L2          0.0926      0.023      4.058      0.000       0.048       0.137
# ma.L3         -0.8876      0.019    -45.850      0.000      -0.926      -0.850
# sigma2        16.9345      0.117    145.010      0.000      16.706      17.163
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.64   Jarque-Bera (JB):            304324.60
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):              18.10   Skew:                            -3.88
# Prob(H) (two-sided):                  0.00   Kurtosis:                        52.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #  Build the model

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data, order=(3,1,3))

fitted=model.fit()

model_summary = fitted.summary()
print(model_summary)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 2922
# Model:                 ARIMA(3, 1, 3)   Log Likelihood               -8279.950
# Date:                Sun, 24 Sep 2023   AIC                          16573.900
# Time:                        22:11:56   BIC                          16615.758
# Sample:                    01-04-2014   HQIC                         16588.977
#                          - 01-03-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0862      0.014     -6.265      0.000      -0.113      -0.059
# ar.L2         -0.2359      0.015    -15.621      0.000      -0.266      -0.206
# ar.L3          0.7841      0.010     77.501      0.000       0.764       0.804
# ma.L1         -0.0958      0.014     -7.016      0.000      -0.123      -0.069
# ma.L2          0.0955      0.017      5.613      0.000       0.062       0.129
# ma.L3         -0.9144      0.013    -72.143      0.000      -0.939      -0.890
# sigma2        16.9944      0.119    142.304      0.000      16.760      17.229
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.81   Jarque-Bera (JB):            309215.21
# Prob(Q):                              0.18   Prob(JB):                         0.00
# Heteroskedasticity (H):              18.50   Skew:                            -3.94
# Prob(H) (two-sided):                  0.00   Kurtosis:                        52.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # Forecasting on test dadaset

# %%
# Forecast
forecast_steps = 361  # Adjust this to your desired number of forecasted time steps
forecast_values = fitted.forecast(steps=forecast_steps)  # Forecast values

# Make as pandas series
fc_series = pd.Series(forecast_values, index=test_data.index)  # Use the appropriate index

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='Training Data')
plt.plot(test_data, color='blue', label='Actual Stock Price')
plt.plot(fc_series, color='orange', label='Predicted Stock Price')
plt.title('AMAZON Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('AMAZON GROUP Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# ##  Evaluating Forecast results

# %%
# report performance
mse = mean_squared_error(test_data, forecast_values)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data, forecast_values)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data, forecast_values))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(forecast_values - test_data)/np.abs(test_data))
print('MAPE: '+str(mape))
# Out:
# MSE: 813.0356934906966
# MAE: 24.171831794986648
# RMSE: 28.51378076458288
# MAPE: 2022-01-04 00:00:00   NaN
# 2022-01-05 00:00:00   NaN
# 2022-01-06 00:00:00   NaN
# 2022-01-07 00:00:00   NaN
# 2022-01-08 00:00:00   NaN
#                        ..
# 2022-12-27 00:00:00   NaN
# 2022-12-28 00:00:00   NaN
# 2022-12-29 00:00:00   NaN
# 2022-12-30 00:00:00   NaN
# close                 NaN
# Length: 362, dtype: float64

# %%
def mean_directional_accuracy(actual, forecasted):
    # Calculate the directional changes in actual and forecasted values
    actual_changes = np.sign(np.diff(actual))
    forecasted_changes = np.sign(np.diff(forecasted))
    
    # Calculate MDA by comparing directional changes
    mda = np.mean(actual_changes == forecasted_changes)
    return mda

# Assuming you have test_data and forecast_values
mda = mean_directional_accuracy(test_data, forecast_values)
print('Mean Directional Accuracy (MDA): {:.2%}'.format(mda))
# Out:
# Mean Directional Accuracy (MDA): 0.00%
