# %%
# !pip install pmdarima
# setting logging to print only error messages from Sklearnex
import logging
logging.basicConfig()
logging.getLogger("SKLEARNEX").setLevel(logging.ERROR)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from datetime import datetime

from statsmodels.tsa.stattools import adfuller,kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima

from sklearn.metrics import mean_squared_error,mean_absolute_error
import math

import warnings
warnings.filterwarnings("ignore")

sns.set_theme(palette="Set2")


def get_mda(y, yhat):
    """Mean Directional Accuracy, as per:
    https://www.wikiwand.com/en/Mean_Directional_Accuracy
    """
    a = np.sign(np.diff(y))
    b = np.sign(np.diff(yhat))
    return np.sum(a == b)/a.shape[0]
# Out:
# Requirement already satisfied: pmdarima in c:\users\akash\anaconda\lib\site-packages (2.0.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: pandas>=0.19 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (61.2.0)
# Requirement already satisfied: urllib3 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.26.9)
# Requirement already satisfied: joblib>=0.11 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\akash\anaconda\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akash\anaconda\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\akash\anaconda\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\akash\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\akash\anaconda\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\akash\anaconda\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\akash\anaconda\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\akash\anaconda\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.4)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\akash\\OneDrive\\Desktop\\ALL CODES\\ARIMA ALL'

# %%
df=pd.read_csv("META  BP DATA.csv")

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close       Volume  \
# 0  01-04-2014  60.459999  62.660000  60.240002  62.619999   59291000.0
# 1  02-04-2014  63.209999  63.910000  62.209999  62.720001   66277000.0
# 2  03-04-2014  62.549999  63.169998  59.130001  59.490002   83859000.0
# 3  04-04-2014  59.939999  60.200001  56.320000  56.750000  125214400.0
# 4  07-04-2014  55.900002  58.000000  55.439999  56.950001  108488000.0
#
#    Day of the week    Change       NASDAQ
# 0              3.0  0.100002  3658.399902
# 1              4.0 -3.229999  3665.989990
# 2              5.0 -2.740002  3637.580078
# 3              6.0  0.200001  3539.379883
# 4              2.0  1.239998  3507.750000

# %%
df=df.dropna()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Volume             0
# Day of the week    0
# Change             0
# NASDAQ             0
# dtype: int64

# %%
df.shape
# Out:
# (2205, 9)

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close      Volume  \
# 2200  23-12-2022  116.029999  118.180000  115.540001  118.040001  17796600.0
# 2201  27-12-2022  117.930000  118.599998  116.050003  116.879997  21392300.0
# 2202  28-12-2022  116.250000  118.150002  115.510002  115.620003  19612500.0
# 2203  29-12-2022  116.400002  121.029999  115.769997  120.260002  22366200.0
# 2204  30-12-2022  118.160004  120.419998  117.739998  120.339996  19583800.0
#
#       Day of the week    Change       NASDAQ
# 2200              6.0 -1.160004  10985.45020
# 2201              3.0 -1.259994  10822.50977
# 2202              4.0  4.639999  10679.33984
# 2203              5.0  0.079994  10951.04981
# 2204              6.0  4.400002  10939.75977

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2205 entries, 0 to 2204
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             2205 non-null   object
#  1   Open             2205 non-null   float64
#  2   High             2205 non-null   float64
#  3   Low              2205 non-null   float64
#  4   Close            2205 non-null   float64
#  5   Volume           2205 non-null   float64
#  6   Day of the week  2205 non-null   float64
#  7   Change           2205 non-null   float64
#  8   NASDAQ           2205 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 172.3+ KB

# %% [markdown]
# ## Convert the "time" column to the datetime type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2205 entries, 0 to 2204
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             2205 non-null   object
#  1   Open             2205 non-null   float64
#  2   High             2205 non-null   float64
#  3   Low              2205 non-null   float64
#  4   Close            2205 non-null   float64
#  5   Volume           2205 non-null   float64
#  6   Day of the week  2205 non-null   float64
#  7   Change           2205 non-null   float64
#  8   NASDAQ           2205 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 172.3+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2205 entries, 0 to 2204
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             2205 non-null   datetime64[ns]
#  1   Open             2205 non-null   float64
#  2   High             2205 non-null   float64
#  3   Low              2205 non-null   float64
#  4   Close            2205 non-null   float64
#  5   Volume           2205 non-null   float64
#  6   Day of the week  2205 non-null   float64
#  7   Change           2205 non-null   float64
#  8   NASDAQ           2205 non-null   float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 172.3 KB

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#                  Open       High        Low      Close       Volume  \
# Date
# 2014-01-04  60.459999  62.660000  60.240002  62.619999   59291000.0
# 2014-02-04  63.209999  63.910000  62.209999  62.720001   66277000.0
# 2014-03-04  62.549999  63.169998  59.130001  59.490002   83859000.0
# 2014-04-04  59.939999  60.200001  56.320000  56.750000  125214400.0
# 2014-07-04  55.900002  58.000000  55.439999  56.950001  108488000.0
#
#             Day of the week    Change       NASDAQ
# Date
# 2014-01-04              3.0  0.100002  3658.399902
# 2014-02-04              4.0 -3.229999  3665.989990
# 2014-03-04              5.0 -2.740002  3637.580078
# 2014-04-04              6.0  0.200001  3539.379883
# 2014-07-04              2.0  1.239998  3507.750000

# %%
df.drop(['Open', 'High','Low','Day of the week','Change','NASDAQ','Volume'], axis=1,inplace=True)

# %%
df
# Out:
#                  Close
# Date
# 2014-01-04   62.619999
# 2014-02-04   62.720001
# 2014-03-04   59.490002
# 2014-04-04   56.750000
# 2014-07-04   56.950001
# ...                ...
# 2022-12-23  118.040001
# 2022-12-27  116.879997
# 2022-12-28  115.620003
# 2022-12-29  120.260002
# 2022-12-30  120.339996
#
# [2205 rows x 1 columns]

# %% [markdown]
# # Missing entries

# %%
min(df.index)
# Out:
# Timestamp('2014-01-04 00:00:00')

# %%
max(df.index)
# Out:
# Timestamp('2022-12-30 00:00:00')

# %%
all_datetimes = pd.date_range(min(df.index), max(df.index), freq="D")
all_datetimes
# Out:
# DatetimeIndex(['2014-01-04', '2014-01-05', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-11',
#                '2014-01-12', '2014-01-13',
#                ...
#                '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-24',
#                '2022-12-25', '2022-12-26', '2022-12-27', '2022-12-28',
#                '2022-12-29', '2022-12-30'],
#               dtype='datetime64[ns]', length=3283, freq='D')

# %%
all_datetimes.shape
# Out:
# (3283,)

# %%
df.shape
# Out:
# (2205, 1)

# %% [markdown]
# # Supplying missing values

# %% [markdown]
#  # Insert missing datetimes

# %%
all_datetimes_df = pd.DataFrame(index=all_datetimes)
all_datetimes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3283 entries, 2014-01-04 to 2022-12-30
# Freq: D
# Empty DataFrame

# %%
df = pd.merge(all_datetimes_df, df, how="left", left_index=True, right_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3283 entries, 2014-01-04 to 2022-12-30
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2205 non-null   float64
# dtypes: float64(1)
# memory usage: 180.3 KB

# %%
plot = df.head(3619).plot(figsize=(20, 12))

# %% [markdown]
# # forward fill

# %%
df["ffilled"] = df["Close"].ffill()
df.head(12)
# Out:
#                 Close    ffilled
# 2014-01-04  62.619999  62.619999
# 2014-01-05  61.150002  61.150002
# 2014-01-06        NaN  61.150002
# 2014-01-07  68.059998  68.059998
# 2014-01-08  72.360001  72.360001
# 2014-01-09        NaN  72.360001
# 2014-01-10  76.550003  76.550003
# 2014-01-11        NaN  76.550003
# 2014-01-12  75.099998  75.099998
# 2014-01-13        NaN  75.099998
# 2014-01-14        NaN  75.099998
# 2014-01-15        NaN  75.099998

# %%
df = df[["ffilled", "Close"]]
plot = df.head(3619).plot(figsize=(20, 12))

# %%
df.ffilled
# Out:
# 2014-01-04     62.619999
# 2014-01-05     61.150002
# 2014-01-06     61.150002
# 2014-01-07     68.059998
# 2014-01-08     72.360001
#                  ...
# 2022-12-26    118.040001
# 2022-12-27    116.879997
# 2022-12-28    115.620003
# 2022-12-29    120.260002
# 2022-12-30    120.339996
# Freq: D, Name: ffilled, Length: 3283, dtype: float64

# %%
df.rename(columns={"ffilled": "close"}, inplace=True)
df
# Out:
#                  close       Close
# 2014-01-04   62.619999   62.619999
# 2014-01-05   61.150002   61.150002
# 2014-01-06   61.150002         NaN
# 2014-01-07   68.059998   68.059998
# 2014-01-08   72.360001   72.360001
# ...                ...         ...
# 2022-12-26  118.040001         NaN
# 2022-12-27  116.879997  116.879997
# 2022-12-28  115.620003  115.620003
# 2022-12-29  120.260002  120.260002
# 2022-12-30  120.339996  120.339996
#
# [3283 rows x 2 columns]

# %%
df.drop(["Close"],axis=1,inplace=True)

# %%
df
# Out:
#                  close
# 2014-01-04   62.619999
# 2014-01-05   61.150002
# 2014-01-06   61.150002
# 2014-01-07   68.059998
# 2014-01-08   72.360001
# ...                ...
# 2022-12-26  118.040001
# 2022-12-27  116.879997
# 2022-12-28  115.620003
# 2022-12-29  120.260002
# 2022-12-30  120.339996
#
# [3283 rows x 1 columns]

# %%
#plot close price
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df['close'])
plt.title('AMAZON closing price')
plt.show()

# %% [markdown]
# # Checking stationarity of the data

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    
    plt.figure(figsize=(18, 10))

    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
test_stationarity(df.close)
# Out:
# Results of dickey fuller test
# Test Statistics                  -1.270421
# p-value                           0.642594
# No. of lags used                 29.000000
# Number of observations used    3253.000000
# critical value (1%)              -3.432362
# critical value (5%)              -2.862429
# critical value (10%)             -2.567243
# dtype: float64

# %% [markdown]
# ## Differencing

# %%
diff_df=df.diff()
diff_df
# Out:
#                close
# 2014-01-04       NaN
# 2014-01-05 -1.469997
# 2014-01-06  0.000000
# 2014-01-07  6.909996
# 2014-01-08  4.300003
# ...              ...
# 2022-12-26  0.000000
# 2022-12-27 -1.160004
# 2022-12-28 -1.259994
# 2022-12-29  4.639999
# 2022-12-30  0.079994
#
# [3283 rows x 1 columns]

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
#split data into train and training set
#train_data, test_data = df[3:int(len(df)*0.9)], df[int(len(df)*0.9):]
train_data = df.loc[df.index < '01-04-2022']
test_data = df.loc[df.index >= '01-04-2022']
plt.figure(figsize=(20,9))
plt.grid(True)
plt.xlabel('Dates',fontsize=14, fontweight='bold')
plt.ylabel('Closing Prices',fontsize=14, fontweight='bold')
plt.plot(df, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %% [markdown]
# # AUTO ARIMA

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=1,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=23131.545, Time=0.62 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=23131.408, Time=0.30 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=23131.249, Time=0.66 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=23129.588, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=22883.998, Time=2.66 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=22865.605, Time=2.59 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=23130.096, Time=0.37 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=22846.408, Time=5.12 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=23129.435, Time=0.96 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=22868.450, Time=7.39 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=22879.905, Time=6.24 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=22855.841, Time=2.26 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0] intercept
# Total fit time: 29.283 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2922
# Model:               SARIMAX(3, 1, 1)   Log Likelihood              -11417.204
# Date:                Tue, 26 Sep 2023   AIC                          22846.408
# Time:                        00:11:03   BIC                          22882.286
# Sample:                    01-04-2014   HQIC                         22859.331
#                          - 01-03-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0221      0.006      3.471      0.001       0.010       0.035
# ar.L1          0.8469      0.015     56.962      0.000       0.818       0.876
# ar.L2         -0.0135      0.019     -0.693      0.488      -0.051       0.025
# ar.L3         -0.0876      0.015     -5.927      0.000      -0.117      -0.059
# ma.L1         -0.9743      0.004   -241.935      0.000      -0.982      -0.966
# sigma2       145.3222      1.442    100.803      0.000     142.497     148.148
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):             31320.26
# Prob(Q):                              0.65   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.99   Skew:                            -1.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #  Build the model

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(train_data, order=(3,1,1))

fitted=model.fit()

model_summary = fitted.summary()
print(model_summary)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 2922
# Model:                 ARIMA(3, 1, 1)   Log Likelihood              -11422.920
# Date:                Tue, 26 Sep 2023   AIC                          22855.841
# Time:                        00:11:12   BIC                          22885.739
# Sample:                    01-04-2014   HQIC                         22866.610
#                          - 01-03-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8453      0.015     57.013      0.000       0.816       0.874
# ar.L2         -0.0134      0.019     -0.697      0.486      -0.051       0.024
# ar.L3         -0.0881      0.015     -5.960      0.000      -0.117      -0.059
# ma.L1         -0.9684      0.005   -211.422      0.000      -0.977      -0.959
# sigma2       145.9033      1.455    100.244      0.000     143.051     148.756
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.42   Jarque-Bera (JB):             31913.89
# Prob(Q):                              0.52   Prob(JB):                         0.00
# Heteroskedasticity (H):              14.00   Skew:                            -1.31
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # Forecasting on test dadaset

# %%
# Forecast
forecast_steps = 361  # Adjust this to your desired number of forecasted time steps
forecast_values = fitted.forecast(steps=forecast_steps)  # Forecast values

# Make as pandas series
fc_series = pd.Series(forecast_values, index=test_data.index)  # Use the appropriate index

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='Training Data')
plt.plot(test_data, color='blue', label='Actual Stock Price')
plt.plot(fc_series, color='orange', label='Predicted Stock Price')
plt.title('AMAZON Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('AMAZON GROUP Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# ##  Evaluating Forecast results

# %%
# report performance
mse = mean_squared_error(test_data, forecast_values)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data, forecast_values)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data, forecast_values))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(forecast_values - test_data)/np.abs(test_data))
print('MAPE: '+str(mape))
# Out:
# MSE: 21455.237732508693
# MAE: 135.75042353135098
# RMSE: 146.47606539127372
# MAPE: 2022-01-04 00:00:00   NaN
# 2022-01-05 00:00:00   NaN
# 2022-01-06 00:00:00   NaN
# 2022-01-07 00:00:00   NaN
# 2022-01-08 00:00:00   NaN
#                        ..
# 2022-12-27 00:00:00   NaN
# 2022-12-28 00:00:00   NaN
# 2022-12-29 00:00:00   NaN
# 2022-12-30 00:00:00   NaN
# close                 NaN
# Length: 362, dtype: float64

# %%
def mean_directional_accuracy(actual, forecasted):
    # Calculate the directional changes in actual and forecasted values
    actual_changes = np.sign(np.diff(actual))
    forecasted_changes = np.sign(np.diff(forecasted))
    
    # Calculate MDA by comparing directional changes
    mda = np.mean(actual_changes == forecasted_changes)
    return mda

# Assuming you have test_data and forecast_values
mda = mean_directional_accuracy(test_data, forecast_values)
print('Mean Directional Accuracy (MDA): {:.2%}'.format(mda))
# Out:
# Mean Directional Accuracy (MDA): 0.00%

# %%
forecast_values
# Out:
# 2022-01-04    219.105647
# 2022-01-05    235.385502
# 2022-01-06    259.118321
# 2022-01-07    277.584396
# 2022-01-08    291.439948
#                  ...
# 2022-12-26    316.167438
# 2022-12-27    316.167438
# 2022-12-28    316.167438
# 2022-12-29    316.167438
# 2022-12-30    316.167438
# Freq: D, Name: predicted_mean, Length: 361, dtype: float64
